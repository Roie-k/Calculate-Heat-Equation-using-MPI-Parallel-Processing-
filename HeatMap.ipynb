# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
a_input = pd.read_excel('HEATMAPinput.xlsx')

# %%
sns.heatmap(a_input,cmap = "PuRd" ,fmt=".0f", linewidths=.5).invert_xaxis()

# %%
output = pd.read_excel('HEATMAPoutput.xlsx')

# %%
sns.heatmap(output,cmap = "PuRd" ,fmt=".0f", linewidths=.5).invert_xaxis()
